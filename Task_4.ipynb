# %%
import random

def play_game_RPS():
    user_score = 0
    computer_score = 0
    choices = ["rock", "paper", "scissors"]
    want_to_play = input("\nWant to play the game? (y/n)").lower()
    if want_to_play == "y":
            print("--- Welcome to Rock-Paper-Scissors! ---")
            print("Instructions: Type 'rock', 'paper', or 'scissors' to play.")
            print("Type 'exit' at any time to end the game.")
    else:
        print("Next Time")
        return

    while True:
        user_choice = input("\nYour choice: ").lower()

        if user_choice == 'exit':
            break
        
        if user_choice not in choices:
            print("Invalid choice. Please try again.")
            continue

        computer_choice = random.choice(choices)
        print(f"Computer chose: {computer_choice}")

        if user_choice == computer_choice:
            print("It's a tie!")
        elif (user_choice == "rock" and computer_choice == "scissors") or \
             (user_choice == "scissors" and computer_choice == "paper") or \
             (user_choice == "paper" and computer_choice == "rock"):
            print("You win this round!")
            user_score += 1
        else:
            print("You lose this round!")
            computer_score += 1

        print(f"Score -> You: {user_score} | Computer: {computer_score}")

        play_again = input("\nPlay another round? (y/n): ").lower()
        if play_again == 'y':
            # This prints the instructions again before the loop restarts
            print("--- Welcome to Rock-Paper-Scissors! ---")
            print("Instructions: Type 'rock', 'paper', or 'scissors' to play.")
            print("Type 'exit' at any time to end the game.")
            continue 
        else:
            break

    print("\nFinal Game Summary")
    print(f"Final Score is You: {user_score} | Computer: {computer_score}")
    print("Thanks for playing!")

if __name__ == "__main__":
    play_game_RPS()
# Out:
# Want to play the game? (y/n) y
# --- Welcome to Rock-Paper-Scissors! ---
# Instructions: Type 'rock', 'paper', or 'scissors' to play.
# Type 'exit' at any time to end the game.
# Your choice:  rock
# Computer chose: paper
# You lose this round!
# Score -> You: 0 | Computer: 1
# Play another round? (y/n):  y
# --- Welcome to Rock-Paper-Scissors! ---
# Instructions: Type 'rock', 'paper', or 'scissors' to play.
# Type 'exit' at any time to end the game.
# Your choice:  rock
# Computer chose: paper
# You lose this round!
# Score -> You: 0 | Computer: 2
# Play another round? (y/n):  n
# Final Game Summary
# Final Score is You: 0 | Computer: 2
# Thanks for playing!
